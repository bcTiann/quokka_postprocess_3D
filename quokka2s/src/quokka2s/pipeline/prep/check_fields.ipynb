# %%
import yt
import numpy as np
from quokka2s.pipeline.prep import physics_fields as phys, config as cfg


ds = yt.load(cfg.YT_DATASET_PATH)
# phys.add_all_fields(ds)
# Out:
# yt : [INFO     ] 2026-04-05 10:08:35,905 Parameters: current_time              = 3180193002532269.5
# yt : [INFO     ] 2026-04-05 10:08:35,905 Parameters: domain_dimensions         = [128 128 512]
# yt : [INFO     ] 2026-04-05 10:08:35,906 Parameters: domain_left_edge          = [ 0.000e+00  0.000e+00 -6.036e+21]
# yt : [INFO     ] 2026-04-05 10:08:35,906 Parameters: domain_right_edge         = [3.018e+21 3.018e+21 6.036e+21]

# %%
ds.derived_field_list
# Out:
# [('StochasticStellarPop_particles', 'birth_time'),
#  ('StochasticStellarPop_particles', 'death_time'),
#  ('StochasticStellarPop_particles', 'luminosity'),
#  ('StochasticStellarPop_particles', 'mass'),
#  ('StochasticStellarPop_particles', 'mesh_id'),
#  ('StochasticStellarPop_particles', 'particle_cpu'),
#  ('StochasticStellarPop_particles', 'particle_id'),
#  ('StochasticStellarPop_particles', 'particle_index'),
#  ('StochasticStellarPop_particles', 'particle_int_comp0'),
#  ('StochasticStellarPop_particles', 'particle_ones'),
#  ('StochasticStellarPop_particles', 'particle_position'),
#  ('StochasticStellarPop_particles', 'particle_position_cylindrical_radius'),
#  ('StochasticStellarPop_particles', 'particle_position_cylindrical_theta'),
#  ('StochasticStellarPop_particles', 'particle_position_cylindrical_z'),
#  ('StochasticStellarPop_particles', 'particle_position_relative_x'),
#  ('StochasticStellarPop_particles', 'particle_position_relative_y'),
# ...

# %%
dd = ds.all_data()
E_int = dd['gas', 'internal_energy_density']
E_kinetic = dd['gas', 'kinetic_energy_density']
E_total = dd['gas', 'total_energy_density']
E_int
E_kinetic
# yt.SlicePlot(ds, "z", ("gas", "density"))
# Out:
# unyt_array([2.81251814e-13, 2.82316984e-13, 2.96832946e-13, ...,
#        1.65030054e-13, 1.50530436e-13, 1.39295447e-13], shape=(8388608,), units='dyn/cm**2')

# %%
yt.SlicePlot(ds, "z", ("gas", "density"))
# Out:
# yt : [INFO     ] 2026-04-05 10:15:18,947 xlim = 0.000000 3018000000000000000000.000000
# yt : [INFO     ] 2026-04-05 10:15:18,947 ylim = 0.000000 3018000000000000000000.000000
# yt : [INFO     ] 2026-04-05 10:15:18,948 xlim = 0.000000 3018000000000000000000.000000
# yt : [INFO     ] 2026-04-05 10:15:18,948 ylim = 0.000000 3018000000000000000000.000000
# yt : [INFO     ] 2026-04-05 10:15:18,949 Making a fixed resolution buffer of (('gas', 'density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
yt.SlicePlot(ds, "z", ('gas', 'kinetic_energy_density'))
# Out:
# yt : [INFO     ] 2026-04-05 10:16:17,244 xlim = 0.000000 3018000000000000000000.000000
# yt : [INFO     ] 2026-04-05 10:16:17,244 ylim = 0.000000 3018000000000000000000.000000
# yt : [INFO     ] 2026-04-05 10:16:17,245 xlim = 0.000000 3018000000000000000000.000000
# yt : [INFO     ] 2026-04-05 10:16:17,245 ylim = 0.000000 3018000000000000000000.000000
# yt : [INFO     ] 2026-04-05 10:16:17,246 Making a fixed resolution buffer of (('gas', 'kinetic_energy_density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
yt.SlicePlot(ds, "z", ('gas', 'internal_energy_density'))
# Out:
# yt : [INFO     ] 2026-04-05 10:17:54,587 xlim = 0.000000 3018000000000000000000.000000
# yt : [INFO     ] 2026-04-05 10:17:54,588 ylim = 0.000000 3018000000000000000000.000000
# yt : [INFO     ] 2026-04-05 10:17:54,588 xlim = 0.000000 3018000000000000000000.000000
# yt : [INFO     ] 2026-04-05 10:17:54,589 ylim = 0.000000 3018000000000000000000.000000
# yt : [INFO     ] 2026-04-05 10:17:54,589 Making a fixed resolution buffer of (('gas', 'internal_energy_density')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>

# %%
yt.SlicePlot(ds, "z", ('gas', 'e-'))
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 yt.SlicePlot(ds, "z", ('gas', 'e-'))
#
# File ~/miniconda3/envs/yt-env/lib/python3.11/site-packages/yt/visualization/plot_window.py:1854, in AxisAlignedSlicePlot.__init__(self, ds, normal, fields, center, width, axes_unit, origin, fontsize, field_parameters, window_size, aspect, data_source, buff_size, north_vector)
#    1846 else:
#    1847     slc = ds.slice(
#    1848         axis,
#    1849         center[axis],
#    (...)   1852         data_source=data_source,
#    1853     )
# -> 1854     slc.get_data(fields)
#    1855 validate_mesh_fields(slc, fields)
#    1856 PWViewerMPL.__init__(
#    1857     self,
#    1858     slc,
#    (...)   1866     geometry=ds.geometry,
#    1867 )
#
# ...

# %%
yt.SlicePlot(ds, "z", ('gas', 'column_density_H'))
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 yt.SlicePlot(ds, "z", ('gas', 'column_density_H'))
#
# File ~/miniconda3/envs/yt-env/lib/python3.11/site-packages/yt/visualization/plot_window.py:1854, in AxisAlignedSlicePlot.__init__(self, ds, normal, fields, center, width, axes_unit, origin, fontsize, field_parameters, window_size, aspect, data_source, buff_size, north_vector)
#    1846 else:
#    1847     slc = ds.slice(
#    1848         axis,
#    1849         center[axis],
#    (...)   1852         data_source=data_source,
#    1853     )
# -> 1854     slc.get_data(fields)
#    1855 validate_mesh_fields(slc, fields)
#    1856 PWViewerMPL.__init__(
#    1857     self,
#    1858     slc,
#    (...)   1866     geometry=ds.geometry,
#    1867 )
#
# ...
